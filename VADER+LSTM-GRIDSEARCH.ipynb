# %%
import math
import nltk
import unicodedata
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as dt
from matplotlib.dates import DateFormatter
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.preprocessing import MinMaxScaler
from keras import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import models as md
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ravie\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ravie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ravie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
company = "TSLA"

# %%
all_stocks = pd.read_csv("stock_yfinance_data.csv")
stock_df = all_stocks[all_stocks['Stock Name'] == company]
stock_df = stock_df.drop('Stock Name', axis=1)
stock_df['Date'] = pd.to_datetime(stock_df['Date']).dt.date
stock_df = stock_df.set_index("Date")
stock_df.dropna()

processed_df = pd.read_csv('tweet_processed_labeled.csv')
processed_df['Date'] = pd.to_datetime(processed_df['Date'])
processed_df['Date'] = processed_df['Date'].dt.date
daily_sentiments_df = processed_df.groupby([processed_df['Date']]).mean(numeric_only=True)

dataset_df = stock_df.copy()
dataset_df = dataset_df.join(daily_sentiments_df, how="left", on="Date")
dataset_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
# ...                ...         ...         ...         ...         ...
# 2022-09-23  283.089996  284.500000  272.820007  275.329987  275.329987
# 2022-09-26  271.829987  284.089996  270.309998  276.010010  276.010010
# 2022-09-27  283.839996  288.670013  277.510010  282.940002  282.940002
# 2022-09-28  283.079987  289.000000  277.570007  287.809998  287.809998
# 2022-09-29  282.760010  283.649994  265.779999  268.209991  268.209991
#
#               Volume  Negative   Neutral  Positive  Compound
# Date
# 2021-09-30  53868000  0.081300  0.739611  0.179067  0.241496
# 2021-10-01  51094200  0.051798  0.811106  0.137106  0.198523
# 2021-10-04  91449900  0.057303  0.821563  0.121118  0.100760
# 2021-10-05  55297800  0.076352  0.796693  0.126989  0.112765
# 2021-10-06  43898400  0.054769  0.771756  0.173500  0.213876
# ...              ...       ...       ...       ...       ...
# 2022-09-23  63748400  0.073233  0.792605  0.134128  0.124760
# 2022-09-26  58076900  0.081292  0.765111  0.153556  0.130479
# 2022-09-27  61925200  0.059835  0.796282  0.143882  0.178928
# 2022-09-28  54664800  0.085640  0.779133  0.135227  0.110548
# 2022-09-29  77620600  0.104089  0.765241  0.130670  0.078079
#
# [252 rows x 10 columns]

# %%
def SplitData(data, train_size, timestep):
    data_values = data.values
    training_data_len = math.ceil(len(data)* train_size)

    scaler = MinMaxScaler(feature_range=(0,1))
    if (len(data_values.shape) == 1):
        scaled_data = scaler.fit_transform(data_values.reshape(-1,1))
    else:
        scaled_data = scaler.fit_transform(data_values)
        scaled_index = scaler.fit_transform(data_values[:, 0:1].flatten().reshape(-1,1))

    train_data = scaled_data[0: training_data_len, :]
    test_data = scaled_data[training_data_len-timestep: , :]

    train_data_x = train_data[0: training_data_len, :]
    train_data_y = train_data[0: training_data_len, 0:1]

    x_train = []
    y_train = []

    for i in range(timestep, len(train_data_x)):
        x_train.append(train_data_x[i-timestep:i])
        y_train.append(train_data_y[i][0])

    x_train, y_train = np.array(x_train), np.array(y_train)
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2]))

    test_data = scaled_data[training_data_len-timestep: , : ]
    x_test = []
    if (len(data_values.shape) == 1):
        y_test = data_values[training_data_len:]
    else:
        y_test = data_values[training_data_len: , 0]

    for i in range(timestep, len(test_data)):
        x_test.append(test_data[i-timestep:i])

    x_test = np.array(x_test)
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], x_test.shape[2]))

    return x_train, y_train, x_test, y_test, scaler

# %%
def TrainModel(x_data, y_data, epoch, neuron_units):

    regressor = Sequential()
    regressor.add(LSTM(units=neuron_units, return_sequences=True, input_shape=(x_data.shape[1], x_data.shape[2])))
    regressor.add(Dropout(0.2))

    regressor.add(LSTM(units=neuron_units, return_sequences=False))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units=1, activation='linear'))

    regressor.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    history = regressor.fit(x_data, y_data, batch_size=1, epochs=epoch, validation_split=0.2)

    return regressor, history

# %%
epochs = [5, 10]
LSTM_units = [16, 32]

# %%
combined_data = dataset_df[['Close', 'Compound']].copy()
train_portion = 0.8
timestep = 60

# %%
finetuning_training_history = []
finetuning_test_data = []

# %%
for i in range(len(epochs)):

    for j in range(len(LSTM_units)):
    
        fig, ax = plt.subplots(figsize=(16, 8))
        ax.set_title('Loss value for ' + str(epochs[i]) + ' epochs and ' + str(LSTM_units[j]) + ' LSTM units')
        ax.set_xlabel('epoch')
        ax.set_ylabel('error value (MSE)')
        ax.xaxis.grid(True, which='both', alpha=0.5)
        ax.yaxis.grid(True, alpha=0.5)

        for k in range(5):

            x_train, y_train, x_test, y_test, scaler = SplitData(combined_data, train_portion, timestep)

            start_time = time.time()
            sentimentModel, history = TrainModel(x_train, y_train, epochs[i], LSTM_units[j])
            end_time = time.time()
            training_time = end_time - start_time

            sentimentModel.save('grid_search_data/saved_model/'+ str(epochs[i]) +'_epochs_'+ str(LSTM_units[j]) +'_units_'+ str(k) +'.keras')

            history_data = history.history
        
            loss_values = history_data['loss']
            val_loss_values = history_data['val_loss']

            finetuning_training_history.append([epochs[i], LSTM_units[j], k, history_data['loss'], history_data['val_loss'], history_data['mae'], history_data['val_mae'], training_time])


            predictions = sentimentModel.predict(x_test)
            predictions = scaler.inverse_transform(predictions)

            mae = np.mean(np.abs(predictions - y_test))
            mse = np.mean((predictions - y_test)**2)
            rmse = np.sqrt(mse)
            mape = np.mean(np.abs((y_test - predictions)/y_test)) * 100

            finetuning_test_data.append([epochs[i], LSTM_units[j], k, mae, mse, rmse, mape, training_time])


            ax.plot(loss_values, color = 'blue')
            ax.plot(val_loss_values, color='red')

        plt.savefig('grid_search_data/'+ str(epochs[i]) +'_epochs_'+ str(LSTM_units[j]) +'_units.png', facecolor=(1, 1, 1))
# Out:
# Epoch 1/5
# 113/113 [==============================] - 15s 61ms/step - loss: 0.0517 - mae: 0.1764 - val_loss: 0.0195 - val_mae: 0.1300
# Epoch 2/5
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0316 - mae: 0.1432 - val_loss: 0.0203 - val_mae: 0.1332
# Epoch 3/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0307 - mae: 0.1420 - val_loss: 0.0173 - val_mae: 0.1212
# Epoch 4/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0241 - mae: 0.1220 - val_loss: 0.0187 - val_mae: 0.1268
# Epoch 5/5
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0220 - mae: 0.1193 - val_loss: 0.0097 - val_mae: 0.0850
# 2/2 [==============================] - 2s 16ms/step
# Epoch 1/5
# 113/113 [==============================] - 14s 59ms/step - loss: 0.0693 - mae: 0.2051 - val_loss: 0.0168 - val_mae: 0.1215
# Epoch 2/5
# 113/113 [==============================] - 5s 42ms/step - loss: 0.
ms/step - loss: 0.0122 - mae: 0.0897 - val_loss: 0.0045 - val_mae: 0.0565
# Epoch 10/10
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0160 - mae: 0.1045 - val_loss: 0.0045 - val_mae: 0.0558
# 2/2 [==============================] - 2s 20ms/step
# Epoch 1/10
# 113/113 [==============================] - 16s 65ms/step - loss: 0.0454 - mae: 0.1702 - val_loss: 0.0343 - val_mae: 0.1772
# Epoch 2/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0241 - mae: 0.1245 - val_loss: 0.0140 - val_mae: 0.1057
# Epoch 3/10
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0235 - mae: 0.1219 - val_loss: 0.0059 - val_mae: 0.0622
# Epoch 4/10
# 113/113 [==============================] - 6s 55ms/step - loss: 0.0224 - mae: 0.1205 - val_loss: 0.0138 - val_mae: 0.1027
# Epoch 5/10
# 113/113 [==============================] - 6s 52ms/step - loss: 0.0162 - mae: 0.1025 - val_loss: 0.0120 - val_mae: 0.0946
# Epoch 6/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0148 - mae: 0.0960 - val_loss: 0.0112 - val_mae: 0.0908
# Epoch 7/10
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0156 - mae: 0.0975 - val_loss: 0.0043 - val_mae: 0.0542
# Epoch 8/10
# 113/113 [==============================] - 5s 49ms/step - loss: 0.0151 - mae: 0.0977 - val_loss: 0.0107 - val_mae: 0.0882
# Epoch 9/10
# 113/113 [==============================] - 7s 59ms/step - loss: 0.0139 - mae: 0.0970 - val_loss: 0.0056 - val_mae: 0.0623
# Epoch 10/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0109 - mae: 0.0858 - val_loss: 0.0049 - val_mae: 0.0581
# 2/2 [==============================] - 2s 21ms/step
# Epoch 1/10
# 113/113 [==============================] - 15s 62ms/step - loss: 0.0533 - mae: 0.1804 - val_loss: 0.0275 - val_mae: 0.1574
# Epoch 2/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0262 - mae: 0.1273 - val_loss: 0.0123 - val_mae: 0.0986
# Epoch 3/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0238 - mae: 0.1236 - val_loss: 0.0141 - val_mae: 0.1073
# Epoch 4/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0193 - mae: 0.1150 - val_loss: 0.0121 - val_mae: 0.0973
# Epoch 5/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0180 - mae: 0.1076 - val_loss: 0.0226 - val_mae: 0.1406
# Epoch 6/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0195 - mae: 0.1140 - val_loss: 0.0275 - val_mae: 0.1570
# Epoch 7/10
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0173 - mae: 0.1086 - val_loss: 0.0051 - val_mae: 0.0580
# Epoch 8/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0176 - mae: 0.1070 - val_loss: 0.0126 - val_mae: 0.0978
# Epoch 9/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0128 - mae: 0.0925 - val_loss: 0.0097 - val_mae: 0.0838
# Epoch 10/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0129 - mae: 0.0928 - val_loss: 0.0149 - val_mae: 0.1088
# 2/2 [==============================] - 2s 19ms/step

# %%
training_finetuning = pd.DataFrame(finetuning_training_history, columns=['#epoch', '#units', '#try', 'loss', 'val_loss', 'mae', 'val_mae', 'train_time'])
training_finetuning.to_csv('grid_search_data/finetuning_training_data.csv', index=False)

# %%
testing_finetuning = pd.DataFrame(finetuning_test_data, columns=['#epoch', '#units', '#try', 'MAE', 'MSE', 'RMSE', 'MAPE', 'train_time'])
testing_finetuning.to_csv('grid_search_data/finetuning_testing_data.csv', index=False)
