# %%
import math
import nltk
import unicodedata
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as dt
from matplotlib.dates import DateFormatter
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.preprocessing import MinMaxScaler
from keras import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import models as md
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ravie\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ravie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ravie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
company = "TSLA"

# %%
all_stocks = pd.read_csv("stock_yfinance_data.csv")
stock_df = all_stocks[all_stocks['Stock Name'] == company]
stock_df = stock_df.drop('Stock Name', axis=1)
stock_df['Date'] = pd.to_datetime(stock_df['Date']).dt.date
stock_df = stock_df.set_index("Date")
stock_df.dropna()

processed_df = pd.read_csv('tweet_processed_labeled.csv')
processed_df['Date'] = pd.to_datetime(processed_df['Date'])
processed_df['Date'] = processed_df['Date'].dt.date
daily_sentiments_df = processed_df.groupby([processed_df['Date']]).mean(numeric_only=True)

dataset_df = stock_df.copy()
dataset_df = dataset_df.join(daily_sentiments_df, how="left", on="Date")
dataset_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
# ...                ...         ...         ...         ...         ...
# 2022-09-23  283.089996  284.500000  272.820007  275.329987  275.329987
# 2022-09-26  271.829987  284.089996  270.309998  276.010010  276.010010
# 2022-09-27  283.839996  288.670013  277.510010  282.940002  282.940002
# 2022-09-28  283.079987  289.000000  277.570007  287.809998  287.809998
# 2022-09-29  282.760010  283.649994  265.779999  268.209991  268.209991
#
#               Volume  Negative   Neutral  Positive  Compound
# Date
# 2021-09-30  53868000  0.081300  0.739611  0.179067  0.241496
# 2021-10-01  51094200  0.051798  0.811106  0.137106  0.198523
# 2021-10-04  91449900  0.057303  0.821563  0.121118  0.100760
# 2021-10-05  55297800  0.076352  0.796693  0.126989  0.112765
# 2021-10-06  43898400  0.054769  0.771756  0.173500  0.213876
# ...              ...       ...       ...       ...       ...
# 2022-09-23  63748400  0.073233  0.792605  0.134128  0.124760
# 2022-09-26  58076900  0.081292  0.765111  0.153556  0.130479
# 2022-09-27  61925200  0.059835  0.796282  0.143882  0.178928
# 2022-09-28  54664800  0.085640  0.779133  0.135227  0.110548
# 2022-09-29  77620600  0.104089  0.765241  0.130670  0.078079
#
# [252 rows x 10 columns]

# %%
def SplitData(data, train_size, timestep):
    data_values = data.values
    training_data_len = math.ceil(len(data)* train_size)

    scaler = MinMaxScaler(feature_range=(0,1))
    if (len(data_values.shape) == 1):
        scaled_data = scaler.fit_transform(data_values.reshape(-1,1))
    else:
        scaled_data = scaler.fit_transform(data_values)
        scaled_index = scaler.fit_transform(data_values[:, 0:1].flatten().reshape(-1,1))

    train_data = scaled_data[0: training_data_len, :]
    test_data = scaled_data[training_data_len-timestep: , :]

    train_data_x = train_data[0: training_data_len, :]
    train_data_y = train_data[0: training_data_len, 0:1]

    x_train = []
    y_train = []

    for i in range(timestep, len(train_data_x)):
        x_train.append(train_data_x[i-timestep:i])
        y_train.append(train_data_y[i][0])

    x_train, y_train = np.array(x_train), np.array(y_train)
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2]))

    test_data = scaled_data[training_data_len-timestep: , : ]
    x_test = []
    if (len(data_values.shape) == 1):
        y_test = data_values[training_data_len:]
    else:
        y_test = data_values[training_data_len: , 0]

    for i in range(timestep, len(test_data)):
        x_test.append(test_data[i-timestep:i])

    x_test = np.array(x_test)
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], x_test.shape[2]))

    return x_train, y_train, x_test, y_test, scaler

# %%
def TrainModel(x_data, y_data, epoch, neuron_units):

    regressor = Sequential()
    regressor.add(LSTM(units=neuron_units, return_sequences=True, input_shape=(x_data.shape[1], x_data.shape[2])))
    regressor.add(Dropout(0.2))

    regressor.add(LSTM(units=neuron_units, return_sequences=False))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units=1, activation='linear'))

    regressor.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    history = regressor.fit(x_data, y_data, batch_size=1, epochs=epoch, validation_split=0.2)

    return regressor, history

# %%
epochs = [5, 10]
LSTM_units = [16, 32]

# %%
combined_data = dataset_df[['Close', 'Compound']].copy()
train_portion = 0.8
timestep = 60

# %%
finetuning_training_history = []
finetuning_test_data = []

# %%
for i in range(len(epochs)):

    for j in range(len(LSTM_units)):
    
        fig, ax = plt.subplots(figsize=(16, 8))
        ax.set_title('Loss value for ' + str(epochs[i]) + ' epochs and ' + str(LSTM_units[j]) + ' LSTM units')
        ax.set_xlabel('epoch')
        ax.set_ylabel('error value (MSE)')
        ax.xaxis.grid(True, which='both', alpha=0.5)
        ax.yaxis.grid(True, alpha=0.5)

        for k in range(5):

            x_train, y_train, x_test, y_test, scaler = SplitData(combined_data, train_portion, timestep)

            start_time = time.time()
            sentimentModel, history = TrainModel(x_train, y_train, epochs[i], LSTM_units[j])
            end_time = time.time()
            training_time = end_time - start_time

            sentimentModel.save('grid_search_data/saved_model/'+ str(epochs[i]) +'_epochs_'+ str(LSTM_units[j]) +'_units_'+ k +'.keras')

            history_data = history.history
        
            loss_values = history_data['loss']
            val_loss_values = history_data['val_loss']

            finetuning_training_history.append([epochs[i], LSTM_units[j], k, history_data['loss'], history_data['val_loss'], history_data['mae'], history_data['val_mae'], training_time])


            predictions = sentimentModel.predict(x_test)
            predictions = scaler.inverse_transform(predictions)

            mae = np.mean(np.abs(predictions - y_test))
            mse = np.mean((predictions - y_test)**2)
            rmse = np.sqrt(mse)
            mape = np.mean(np.abs((y_test - predictions)/y_test)) * 100

            finetuning_test_data.append([epochs[i], LSTM_units[j], k, mae, mse, rmse, mape, training_time])


            ax.plot(loss_values, color = 'blue')
            ax.plot(val_loss_values, color='red')

        plt.savefig('grid_search_data/'+ str(epochs[i]) +'_epochs_'+ str(LSTM_units[j]) +'_units.png', facecolor=(1, 1, 1))
# Out:
# Epoch 1/5
# 113/113 [==============================] - 14s 55ms/step - loss: 0.0511 - mae: 0.1826 - val_loss: 0.0152 - val_mae: 0.1130
# Epoch 2/5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.0306 - mae: 0.1408 - val_loss: 0.0179 - val_mae: 0.1240
# Epoch 3/5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0278 - mae: 0.1326 - val_loss: 0.0191 - val_mae: 0.1291
# Epoch 4/5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0239 - mae: 0.1258 - val_loss: 0.0395 - val_mae: 0.1924
# Epoch 5/5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.0226 - mae: 0.1204 - val_loss: 0.0084 - val_mae: 0.0775
# 2/2 [==============================] - 2s 14ms/step
# Epoch 1/5
# 113/113 [==============================] - 14s 66ms/step - loss: 0.0380 - mae: 0.1561 - val_loss: 0.0396 - val_mae: 0.1923
# Epoch 2/5
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0260 - mae: 0.1261 - val_loss: 0.0029 - val_mae: 0.0389
# Epoch 3/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0226 - mae: 0.1162 - val_loss: 0.0177 - val_mae: 0.1224
# Epoch 4/5
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0271 - mae: 0.1325 - val_loss: 0.0140 - val_mae: 0.1061
# Epoch 5/5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0214 - mae: 0.1155 - val_loss: 0.0172 - val_mae: 0.1196
# 2/2 [==============================] - 2s 21ms/step
# Epoch 1/5
# 113/113 [==============================] - 14s 55ms/step - loss: 0.0655 - mae: 0.1970 - val_loss: 0.0217 - val_mae: 0.1377
# Epoch 2/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0353 - mae: 0.1576 - val_loss: 0.0520 - val_mae: 0.2215
# Epoch 3/5
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0291 - mae: 0.1399 - val_loss: 0.0141 - val_mae: 0.1061
# Epoch 4/5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.0242 - mae: 0.1239 - val_loss: 0.0183 - val_mae: 0.1237
# Epoch 5/5
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0229 - mae: 0.1190 - val_loss: 0.0151 - val_mae: 0.1096
# 2/2 [==============================] - 2s 16ms/step
# Epoch 1/5
# 113/113 [==============================] - 14s 58ms/step - loss: 0.0548 - mae: 0.1885 - val_loss: 0.0166 - val_mae: 0.1174
# Epoch 2/5
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0340 - mae: 0.1467 - val_loss: 0.0144 - val_mae: 0.1075
# Epoch 3/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0293 - mae: 0.1380 - val_loss: 0.0141 - val_mae: 0.1063
# Epoch 4/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0237 - mae: 0.1276 - val_loss: 0.0225 - val_mae: 0.1399
# Epoch 5/5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0272 - mae: 0.1322 - val_loss: 0.0177 - val_mae: 0.1214
# 2/2 [==============================] - 2s 14ms/step
# Epoch 1/5
# 113/113 [==============================] - 16s 63ms/step - loss: 0.0506 - mae: 0.1813 - val_loss: 0.0198 - val_mae: 0.1295
# Epoch 2/5
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0345 - mae: 0.1522 - val_loss: 0.0071 - val_mae: 0.0679
# Epoch 3/5
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0247 - mae: 0.1255 - val_loss: 0.0093 - val_mae: 0.0799
# Epoch 4/5
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0239 - mae: 0.1220 - val_loss: 0.0091 - val_mae: 0.0790
# Epoch 5/5
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0219 - mae: 0.1194 - val_loss: 0.0088 - val_mae: 0.0778
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002CA20F35FC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 2s 17ms/step
# Epoch 1/5
# 113/113 [==============================] - 15s 54ms/step - loss: 0.0599 - mae: 0.1955 - val_loss: 0.0095 - val_mae: 0.0832
# Epoch 2/5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0283 - mae: 0.1306 - val_loss: 0.0138 - val_mae: 0.1048
# Epoch 3/5
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0259 - mae: 0.1270 - val_loss: 0.0348 - val_mae: 0.1783
# Epoch 4/5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0213 - mae: 0.1134 - val_loss: 0.0348 - val_mae: 0.1777
# Epoch 5/5
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0176 - mae: 0.1053 - val_loss: 0.0187 - val_mae: 0.1240
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002CA20833F40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 2s 16ms/step
# Epoch 1/5
# 113/113 [==============================] - 15s 66ms/step - loss: 0.0594 - mae: 0.1847 - val_loss: 0.0158 - val_mae: 0.1144
# Epoch 2/5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0241 - mae: 0.1229 - val_loss: 0.0110 - val_mae: 0.0909
# Epoch 3/5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0194 - mae: 0.1091 - val_loss: 0.0209 - val_mae: 0.1334
# Epoch 4/5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0188 - mae: 0.1087 - val_loss: 0.0095 - val_mae: 0.0822
# Epoch 5/5
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0181 - mae: 0.1094 - val_loss: 0.0129 - val_mae: 0.0980
# 2/2 [==============================] - 2s 17ms/step
# Epoch 1/5
# 113/113 [==============================] - 13s 57ms/step - loss: 0.0401 - mae: 0.1598 - val_loss: 0.0049 - val_mae: 0.0548
# Epoch 2/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0258 - mae: 0.1314 - val_loss: 0.0113 - val_mae: 0.0931
# Epoch 3/5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0215 - mae: 0.1174 - val_loss: 0.0054 - val_mae: 0.0588
# Epoch 4/5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0190 - mae: 0.1118 - val_loss: 0.0080 - val_mae: 0.0747
# Epoch 5/5
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0152 - mae: 0.0983 - val_loss: 0.0086 - val_mae: 0.0773
# 2/2 [==============================] - 2s 21ms/step
# Epoch 1/5
# 113/113 [==============================] - 15s 71ms/step - loss: 0.0509 - mae: 0.1719 - val_loss: 0.0157 - val_mae: 0.1150
# Epoch 2/5
# 113/113 [==============================] - 6s 54ms/step - loss: 0.0240 - mae: 0.1212 - val_loss: 0.0164 - val_mae: 0.1172
# Epoch 3/5
# 113/113 [==============================] - 6s 53ms/step - loss: 0.0195 - mae: 0.1096 - val_loss: 0.0086 - val_mae: 0.0782
# Epoch 4/5
# 113/113 [==============================] - 6s 52ms/step - loss: 0.0188 - mae: 0.1115 - val_loss: 0.0182 - val_mae: 0.1234
# Epoch 5/5
# 113/113 [==============================] - 6s 53ms/step - loss: 0.0203 - mae: 0.1113 - val_loss: 0.0173 - val_mae: 0.1193
# 2/2 [==============================] - 2s 22ms/step
# Epoch 1/5
# 113/113 [==============================] - 19s 70ms/step - loss: 0.0522 - mae: 0.1788 - val_loss: 0.0059 - val_mae: 0.0610
# Epoch 2/5
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0276 - mae: 0.1313 - val_loss: 0.0129 - val_mae: 0.1001
# Epoch 3/5
# 113/113 [==============================] - 6s 49ms/step - loss: 0.0215 - mae: 0.1153 - val_loss: 0.0191 - val_mae: 0.1265
# Epoch 4/5
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0173 - mae: 0.1056 - val_loss: 0.0086 - val_mae: 0.0766
# Epoch 5/5
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0205 - mae: 0.1197 - val_loss: 0.0107 - val_mae: 0.0876
# 2/2 [==============================] - 2s 20ms/step
# Epoch 1/10
# 113/113 [==============================] - 16s 70ms/step - loss: 0.0934 - mae: 0.2377 - val_loss: 0.0371 - val_mae: 0.1862
# Epoch 2/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0341 - mae: 0.1488 - val_loss: 0.0372 - val_mae: 0.1861
# Epoch 3/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0331 - mae: 0.1465 - val_loss: 0.0239 - val_mae: 0.1459
# Epoch 4/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0262 - mae: 0.1323 - val_loss: 0.0231 - val_mae: 0.1429
# Epoch 5/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0220 - mae: 0.1188 - val_loss: 0.0170 - val_mae: 0.1194
# Epoch 6/10
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0228 - mae: 0.1225 - val_loss: 0.0166 - val_mae: 0.1175
# Epoch 7/10
# 113/113 [==============================] - 6s 49ms/step - loss: 0.0166 - mae: 0.1025 - val_loss: 0.0140 - val_mae: 0.1056
# Epoch 8/10
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0195 - mae: 0.1139 - val_loss: 0.0159 - val_mae: 0.1138
# Epoch 9/10
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0169 - mae: 0.1055 - val_loss: 0.0265 - val_mae: 0.1533
# Epoch 10/10
# 113/113 [==============================] - 5s 49ms/step - loss: 0.0143 - mae: 0.0944 - val_loss: 0.0054 - val_mae: 0.0584
# 2/2 [==============================] - 2s 21ms/step
# Epoch 1/10
# 113/113 [==============================] - 18s 69ms/step - loss: 0.0525 - mae: 0.1884 - val_loss: 0.0369 - val_mae: 0.1841
# Epoch 2/10
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0328 - mae: 0.1468 - val_loss: 0.0107 - val_mae: 0.0888
# Epoch 3/10
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0238 - mae: 0.1224 - val_loss: 0.0112 - val_mae: 0.0913
# Epoch 4/10
# 113/113 [==============================] - 6s 54ms/step - loss: 0.0303 - mae: 0.1328 - val_loss: 0.0183 - val_mae: 0.1238
# Epoch 5/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0213 - mae: 0.1169 - val_loss: 0.0106 - val_mae: 0.0874
# Epoch 6/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0198 - mae: 0.1135 - val_loss: 0.0059 - val_mae: 0.0615
# Epoch 7/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0177 - mae: 0.1047 - val_loss: 0.0048 - val_mae: 0.0537
# Epoch 8/10
# 113/113 [==============================] - 6s 54ms/step - loss: 0.0175 - mae: 0.1018 - val_loss: 0.0156 - val_mae: 0.1102
# Epoch 9/10
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0192 - mae: 0.1028 - val_loss: 0.0050 - val_mae: 0.0543
# Epoch 10/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0171 - mae: 0.1036 - val_loss: 0.0122 - val_mae: 0.0945
# 2/2 [==============================] - 2s 18ms/step
# Epoch 1/10
# 113/113 [==============================] - 14s 58ms/step - loss: 0.0641 - mae: 0.1974 - val_loss: 0.0276 - val_mae: 0.1585
# Epoch 2/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0310 - mae: 0.1420 - val_loss: 0.0274 - val_mae: 0.1577
# Epoch 3/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0251 - mae: 0.1282 - val_loss: 0.0128 - val_mae: 0.1015
# Epoch 4/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0224 - mae: 0.1210 - val_loss: 0.0220 - val_mae: 0.1392
# Epoch 5/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0231 - mae: 0.1222 - val_loss: 0.0077 - val_mae: 0.0728
# Epoch 6/10
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0196 - mae: 0.1078 - val_loss: 0.0115 - val_mae: 0.0932
# Epoch 7/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0174 - mae: 0.1039 - val_loss: 0.0100 - val_mae: 0.0853
# Epoch 8/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0180 - mae: 0.1077 - val_loss: 0.0074 - val_mae: 0.0716
# Epoch 9/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0137 - mae: 0.0991 - val_loss: 0.0085 - val_mae: 0.0775
# Epoch 10/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0162 - mae: 0.1026 - val_loss: 0.0077 - val_mae: 0.0730
# 2/2 [==============================] - 2s 15ms/step
# Epoch 1/10
# 113/113 [==============================] - 15s 60ms/step - loss: 0.0603 - mae: 0.1931 - val_loss: 0.0316 - val_mae: 0.1701
# Epoch 2/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0328 - mae: 0.1498 - val_loss: 0.0343 - val_mae: 0.1777
# Epoch 3/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0219 - mae: 0.1133 - val_loss: 0.0168 - val_mae: 0.1186
# Epoch 4/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0264 - mae: 0.1313 - val_loss: 0.0134 - val_mae: 0.1025
# Epoch 5/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0223 - mae: 0.1227 - val_loss: 0.0180 - val_mae: 0.1223
# Epoch 6/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0194 - mae: 0.1134 - val_loss: 0.0159 - val_mae: 0.1120
# Epoch 7/10
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0186 - mae: 0.1133 - val_loss: 0.0116 - val_mae: 0.0912
# Epoch 8/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0180 - mae: 0.1062 - val_loss: 0.0078 - val_mae: 0.0728
# Epoch 9/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0158 - mae: 0.1000 - val_loss: 0.0117 - val_mae: 0.0927
# Epoch 10/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0180 - mae: 0.1068 - val_loss: 0.0077 - val_mae: 0.0732
# 2/2 [==============================] - 3s 21ms/step
# Epoch 1/10
# 113/113 [==============================] - 15s 64ms/step - loss: 0.0531 - mae: 0.1868 - val_loss: 0.0085 - val_mae: 0.0794
# Epoch 2/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0311 - mae: 0.1403 - val_loss: 0.0071 - val_mae: 0.0711
# Epoch 3/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0256 - mae: 0.1380 - val_loss: 0.0133 - val_mae: 0.1053
# Epoch 4/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0267 - mae: 0.1258 - val_loss: 0.0166 - val_mae: 0.1196
# Epoch 5/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0252 - mae: 0.1240 - val_loss: 0.0111 - val_mae: 0.0940
# Epoch 6/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0201 - mae: 0.1113 - val_loss: 0.0066 - val_mae: 0.0674
# Epoch 7/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0222 - mae: 0.1154 - val_loss: 0.0193 - val_mae: 0.1301
# Epoch 8/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0154 - mae: 0.1002 - val_loss: 0.0137 - val_mae: 0.1059
# Epoch 9/10
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0195 - mae: 0.1147 - val_loss: 0.0109 - val_mae: 0.0917
# Epoch 10/10
# 113/113 [==============================] - 4s 38ms/step - loss: 0.0211 - mae: 0.1163 - val_loss: 0.0102 - val_mae: 0.0878
# 2/2 [==============================] - 2s 16ms/step
# Epoch 1/10
# 113/113 [==============================] - 15s 68ms/step - loss: 0.0335 - mae: 0.1505 - val_loss: 0.0122 - val_mae: 0.0983
# Epoch 2/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0210 - mae: 0.1142 - val_loss: 0.0213 - val_mae: 0.1369
# Epoch 3/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0209 - mae: 0.1094 - val_loss: 0.0197 - val_mae: 0.1308
# Epoch 4/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0168 - mae: 0.1055 - val_loss: 0.0163 - val_mae: 0.1163
# Epoch 5/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0163 - mae: 0.1032 - val_loss: 0.0093 - val_mae: 0.0821
# Epoch 6/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0156 - mae: 0.0998 - val_loss: 0.0079 - val_mae: 0.0741
# Epoch 7/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0133 - mae: 0.0943 - val_loss: 0.0040 - val_mae: 0.0510
# Epoch 8/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0196 - mae: 0.1120 - val_loss: 0.0139 - val_mae: 0.1053
# Epoch 9/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0115 - mae: 0.0871 - val_loss: 0.0063 - val_mae: 0.0655
# Epoch 10/10
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0168 - mae: 0.1055 - val_loss: 0.0055 - val_mae: 0.0615
# 2/2 [==============================] - 2s 21ms/step
# Epoch 1/10
# 113/113 [==============================] - 16s 64ms/step - loss: 0.0404 - mae: 0.1562 - val_loss: 0.0220 - val_mae: 0.1390
# Epoch 2/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0259 - mae: 0.1318 - val_loss: 0.0076 - val_mae: 0.0734
# Epoch 3/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0211 - mae: 0.1162 - val_loss: 0.0188 - val_mae: 0.1279
# Epoch 4/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0197 - mae: 0.1164 - val_loss: 0.0181 - val_mae: 0.1249
# Epoch 5/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0155 - mae: 0.0979 - val_loss: 0.0106 - val_mae: 0.0903
# Epoch 6/10
# 113/113 [==============================] - 4s 38ms/step - loss: 0.0161 - mae: 0.1021 - val_loss: 0.0137 - val_mae: 0.1055
# Epoch 7/10
# 113/113 [==============================] - 4s 38ms/step - loss: 0.0165 - mae: 0.1003 - val_loss: 0.0087 - val_mae: 0.0801
# Epoch 8/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0144 - mae: 0.0920 - val_loss: 0.0091 - val_mae: 0.0818
# Epoch 9/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0144 - mae: 0.0959 - val_loss: 0.0030 - val_mae: 0.0488
# Epoch 10/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0115 - mae: 0.0879 - val_loss: 0.0205 - val_mae: 0.1327
# 2/2 [==============================] - 3s 22ms/step
# Epoch 1/10
# 113/113 [==============================] - 15s 65ms/step - loss: 0.0397 - mae: 0.1538 - val_loss: 0.0149 - val_mae: 0.1116
# Epoch 2/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0286 - mae: 0.1372 - val_loss: 0.0084 - val_mae: 0.0771
# Epoch 3/10
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0215 - mae: 0.1129 - val_loss: 0.0172 - val_mae: 0.1198
# Epoch 4/10
# 113/113 [==============================] - 6s 49ms/step - loss: 0.0137 - mae: 0.0959 - val_loss: 0.0122 - val_mae: 0.0963
# Epoch 5/10
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0150 - mae: 0.0980 - val_loss: 0.0078 - val_mae: 0.0733
# Epoch 6/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0147 - mae: 0.0995 - val_loss: 0.0097 - val_mae: 0.0838
# Epoch 7/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0121 - mae: 0.0878 - val_loss: 0.0088 - val_mae: 0.0793
# Epoch 8/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0148 - mae: 0.0989 - val_loss: 0.0093 - val_mae: 0.0815
# Epoch 9/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0139 - mae: 0.0962 - val_loss: 0.0091 - val_mae: 0.0807
# Epoch 10/10
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0135 - mae: 0.0943 - val_loss: 0.0081 - val_mae: 0.0752
# 2/2 [==============================] - 2s 29ms/step
# Epoch 1/10
# 113/113 [==============================] - 16s 65ms/step - loss: 0.0566 - mae: 0.1820 - val_loss: 0.0189 - val_mae: 0.1285
# Epoch 2/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0279 - mae: 0.1357 - val_loss: 0.0233 - val_mae: 0.1447
# Epoch 3/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0239 - mae: 0.1215 - val_loss: 0.0173 - val_mae: 0.1222
# Epoch 4/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0226 - mae: 0.1187 - val_loss: 0.0184 - val_mae: 0.1256
# Epoch 5/10
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0190 - mae: 0.1088 - val_loss: 0.0116 - val_mae: 0.0948
# Epoch 6/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0187 - mae: 0.1089 - val_loss: 0.0077 - val_mae: 0.0732
# Epoch 7/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0164 - mae: 0.1056 - val_loss: 0.0081 - val_mae: 0.0752
# Epoch 8/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0134 - mae: 0.0949 - val_loss: 0.0131 - val_mae: 0.1022
# Epoch 9/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0135 - mae: 0.0941 - val_loss: 0.0029 - val_mae: 0.0430
# Epoch 10/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0133 - mae: 0.0943 - val_loss: 0.0210 - val_mae: 0.1348
# 2/2 [==============================] - 3s 21ms/step
# Epoch 1/10
# 113/113 [==============================] - 13s 56ms/step - loss: 0.0405 - mae: 0.1588 - val_loss: 0.0175 - val_mae: 0.1206
# Epoch 2/10
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0262 - mae: 0.1284 - val_loss: 0.0259 - val_mae: 0.1507
# Epoch 3/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0219 - mae: 0.1191 - val_loss: 0.0123 - val_mae: 0.0962
# Epoch 4/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0220 - mae: 0.1180 - val_loss: 0.0164 - val_mae: 0.1140
# Epoch 5/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0192 - mae: 0.1142 - val_loss: 0.0200 - val_mae: 0.1287
# Epoch 6/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0149 - mae: 0.1032 - val_loss: 0.0078 - val_mae: 0.0734
# Epoch 7/10
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0130 - mae: 0.0929 - val_loss: 0.0049 - val_mae: 0.0545
# Epoch 8/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0171 - mae: 0.1072 - val_loss: 0.0125 - val_mae: 0.0963
# Epoch 9/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0131 - mae: 0.0944 - val_loss: 0.0165 - val_mae: 0.1139
# Epoch 10/10
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0190 - mae: 0.1112 - val_loss: 0.0156 - val_mae: 0.1097
# 2/2 [==============================] - 3s 26ms/step

# %%
training_finetuning = pd.DataFrame(finetuning_training_history, columns=['#epoch', '#units', '#try', 'loss', 'val_loss', 'mae', 'val_mae', 'train_time'])
training_finetuning.to_csv('grid_search_data/finetuning_training_data.csv', index=False)

# %%
testing_finetuning = pd.DataFrame(finetuning_test_data, columns=['#epoch', '#units', '#try', 'MAE', 'MSE', 'RMSE', 'MAPE', 'train_time'])
testing_finetuning.to_csv('grid_search_data/finetuning_testing_data.csv', index=False)
